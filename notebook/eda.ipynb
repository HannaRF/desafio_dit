# %%
import pandas as pd
import seaborn as sns
import os

# %%
df = pd.read_csv(r'..\data\raw\dados_ficha_a_desafio.csv')

# %%
df.shape
# Out:
# (100000, 35)

# %%
df.head(1).transpose()
# Out:
#                                                                           0
# id_paciente                            cd6daa6e-038d-4952-af29-579e62e07f97
# sexo                                                                   male
# obito                                                                     0
# bairro                                                      Parada de Lucas
# raca_cor                                                             Branca
# ocupacao                                                      Não se aplica
# religiao                                                       Sem religião
# luz_eletrica                                                           True
# data_cadastro                                       2021-06-24 00:00:00.000
# escolaridade                                         Fundamental Incompleto
# nacionalidade                                                    Brasileira
# ...

# %% [markdown]
# ### Exploração e apontamento de problemas

# %% [markdown]
# #### 1. Explore e analise cada um dos campos disponíveis entendendo o tipo de preenchimento que possuem.
